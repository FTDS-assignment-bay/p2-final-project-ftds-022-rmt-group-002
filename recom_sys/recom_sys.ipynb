# %% [markdown]
# # Import library

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Data loading

# %%
bli_df = pd.read_csv('../data_engineering/BlibliMas_clean_latest.csv')
bulak_df = pd.read_csv('../data_engineering/BukalapakMas_clean_latest.csv')
tokped_df = pd.read_csv('../data_engineering/TokMas_clean_latest.csv')
gold_price_latest = pd.read_csv('../data_engineering/HargaEmas_clean_latest.csv')

# %%
print(bli_df.shape)
bli_df.head()
# Out:
# (29, 7)
#                                         product_name    price  \
# 0          ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 1  Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...  1115420
# 2  BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...  1095000
# 3  Hartadinata X Antam Logam Mulia Keping Emas [1...  1060000
# 4  SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...  1095000
#
#                         seller              location  number_sold  rating  \
# 0    de yellow official store    Kota Jakarta Utara         37000     4.9
# 1   victorindo official store    Kota Jakarta Pusat             2     5.0
# 2      bligold official store          Kota Bandung            77     4.9
# 3                    my jewel    Kota Jakarta Pusat           181     4.9
# 4      bligold official store         Kota Semarang            56     5.0
#
#                                                 link
# 0  https://www.blibli.com/p/antam-lm-emas-1-gram-...
# 1  https://www.blibli.com/p/logam-mulia-emas-anta...
# 2  https://www.blibli.com/p/bandung-bligold-antam...
# 3  https://www.blibli.com/p/hartadinata-x-antam-l...
# 4  https://www.blibli.com/p/semarang-bligold-anta...

# %%
bulak_df
# Out:
#                                          product_name    price  \
# 0   LOGAM MULIA EMAS ANTAM 1 Gram MURAH DAN BERSER...  1109900
# 1   Logam mulia emas antam murni 1 gram murah dan ...  1109900
# 2   LOGAM MULIA EMAS ANTAM 1 GRAM MURAH DAN BERSER...  1109000
# 3   ASLI Antam 1 gram Logam Mulia Emas Murni 24 Ka...  1099000
# 4      LM Logam Mulia Emas Antam 1 gram Certieye BUMN  1195000
# ..                                                ...      ...
# 72                        Emas Antam 1 Gram Certicard  1105500
# 73  Emas 1 Gr Antam Logam Mulia Gram G New 2019 Se...  1094000
# 74                      Logam Mulia Emas Antam 1 Gram  1150000
# 75  Emas antam 1 gram bersertifikat asli - logam m...  1125000
# 76  emas Antam 1 gram 2022 Certieye, emas logam mu...  1150000
#
#                 seller         location  number_sold  rating  \
# 0        Adamsay Store         Sidoarjo           65     5.0
# 1        Adamsay Store         Sidoarjo          558     4.9
# 2        Adamsay Store         Sidoarjo           41     5.0
# 3   Nawla Jam Original         Surabaya          339     5.0
# 4            DAMI CELL    Jakarta Barat           10     5.0
# ..                 ...              ...          ...     ...
# 72     Pradiana Shoppe       Kab. Bogor            0     0.0
# 73          Fuyyu Shop  Jakarta Selatan            0     0.0
# 74           Toko Bima         Surabaya            2     5.0
# 75             EROSHOP            Depok           28     4.9
# 76      toserba_blitar      Kab. Blitar            0     0.0
#
#                                                  link
# 0   https://www.bukalapak.com/p/logam-mulia/m2osk1...
# 1   https://www.bukalapak.com/p/logam-mulia/hi7thq...
# 2   https://www.bukalapak.com/p/logam-mulia/m2oqet...
# 3   https://www.bukalapak.com/p/logam-mulia/emas/4...
# 4   https://www.bukalapak.com/p/logam-mulia/emas/4...
# ..                                                ...
# 72  https://www.bukalapak.com/p/logam-mulia/emas/4...
# 73  https://www.bukalapak.com/p/fashion-wanita/per...
# 74  https://www.bukalapak.com/p/hobi-koleksi/kolek...
# 75  https://www.bukalapak.com/p/fashion-wanita/per...
# 76  https://www.bukalapak.com/p/logam-mulia/emas/4...
#
# [77 rows x 7 columns]

# %%
tokped_df
# Out:
#                                           product_name     price  \
# 0    Emas Antam 1 Gram Certicard + Box Gratis Kartu...   1279000
# 1    LM Emas Antam 1 gram Happy Wedding Gift Series...   1262250
# 2     Logam Mulia Press 1 gram baru certieye bs plterr   1245000
# 3    EMAS ANTAM 1 Gram - 25 Gram Logam Mulia LM Ant...   1012000
# 4      Logam Mulia Emas Antam 1 gram Press Certieye LM   1103950
# ..                                                 ...       ...
# 235                            Antam Indonesia premium    150000
# 236  Emas Antam 50 Gram Certicard Reinvented Certie...  51533000
# 237               Logam Mulia 10 gram diri bs plltterr  10750000
# 238  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...   1167500
# 239                           Lotus Archi 1gr CertiEye   1085000
#
#                seller         location  number_sold  rating  \
# 0    Calvina Galleria  Jakarta Selatan         1000     5.0
# 1       Toko Igunawan    Jakarta Timur          500     5.0
# 2    TOKO MAS DYNASTY    Jakarta Pusat          250     5.0
# 3                KAAF   Kab. Tangerang           20     5.0
# 4     Dover Fine Gold         Surabaya         1000     5.0
# ..                ...              ...          ...     ...
# 235      Mulia Cikini    Jakarta Pusat           50     5.0
# 236          RVL Gold    Jakarta Timur            0     0.0
# 237  TOKO MAS DYNASTY    Jakarta Pusat           12     5.0
# 238  Altisar Official    Jakarta Timur           15     5.0
# 239        LotusArchi  Jakarta Selatan        10000     5.0
#
#                                                   link
# 0    https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 1    https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 2    https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 3    https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 4    https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# ..                                                 ...
# 235  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 236  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 237  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 238  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 239  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
#
# [240 rows x 7 columns]

# %%
gold_price_latest
# Out:
#               datetime    price  year  month  day
# 0  2023-10-11 08:18:25  1063000  2023     10   11

# %%
store_df = pd.concat([bli_df, bulak_df, tokped_df], ignore_index=True)
store_df
# Out:
#                                           product_name     price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU   1095000
# 1    Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...   1115420
# 2    BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...   1095000
# 3    Hartadinata X Antam Logam Mulia Keping Emas [1...   1060000
# 4    SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...   1095000
# ..                                                 ...       ...
# 341                            Antam Indonesia premium    150000
# 342  Emas Antam 50 Gram Certicard Reinvented Certie...  51533000
# 343               Logam Mulia 10 gram diri bs plltterr  10750000
# 344  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...   1167500
# 345                           Lotus Archi 1gr CertiEye   1085000
#
#                           seller              location  number_sold  rating  \
# 0      de yellow official store    Kota Jakarta Utara         37000     4.9
# 1     victorindo official store    Kota Jakarta Pusat             2     5.0
# 2        bligold official store          Kota Bandung            77     4.9
# 3                      my jewel    Kota Jakarta Pusat           181     4.9
# 4        bligold official store         Kota Semarang            56     5.0
# ..                           ...                   ...          ...     ...
# 341                 Mulia Cikini         Jakarta Pusat           50     5.0
# 342                     RVL Gold         Jakarta Timur            0     0.0
# 343             TOKO MAS DYNASTY         Jakarta Pusat           12     5.0
# 344             Altisar Official         Jakarta Timur           15     5.0
# 345                   LotusArchi       Jakarta Selatan        10000     5.0
#
#                                                   link
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...
# 1    https://www.blibli.com/p/logam-mulia-emas-anta...
# 2    https://www.blibli.com/p/bandung-bligold-antam...
# 3    https://www.blibli.com/p/hartadinata-x-antam-l...
# 4    https://www.blibli.com/p/semarang-bligold-anta...
# ..                                                 ...
# 341  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 342  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 343  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 344  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 345  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
#
# [346 rows x 7 columns]

# %%
store_df[(store_df['product_name'].str.contains('ANTAM') == False) & (store_df['product_name'].str.contains('Antam') == False) &
        (store_df['product_name'].str.contains('antam') == False)]
# Out:
#                                           product_name     price  \
# 18               EmasKITA Birthday Bullionprotect 1 Gr   1043136
# 19         EmasKITA Wedding Inter BullionProtect® 1 Gr   1043136
# 108   Logam Mulia Press 1 gram baru certieye bs plterr   1245000
# 123  Logam Mulia 1 gram press terbaru certieye bisa...   1245000
# 181       Logam Mulia 2 gram press terbaru bisa plterr   2450000
# 183       Logam Mulia 10 gram press terbaru bs pltterr  11500000
# 185              RM 1 gram terbaru certieye bs plterrr   1245000
# 203    Rangka Cincin Emas 18K Solitaire - AG Jewellery   4100000
# 205  Little Mermaid - Aurum Lab - Mystical Voice (C...   1429826
# 217  [ GRA - SERTIFIKAT ] LEMON - YELLOW 100% BERLI...    198000
# 219  Cincin Emas 7K - Charming Gold Ring - Allura -...    874125
# 220                Logam Mulia 3 gram diri bs plltterr   3395000
# 262   Logam Mulia 0.5 gram terbaru certieye bs pltterr    695000
# 264  Emas Dinar Public Gold Singapore - 1 Dinar 4,2...   4650000
# 265  Logam Mulia Emasin Gold kemasan CUSTOM Suka-su...    314000
# 267  Logam mulia emas 24k 0,2 - 1gr edisi happy bir...    240200
# 282                Logam Mulia 4 gram diri bs plltterr   4395000
# 285  Emas Royal Mint James Bond- Diamonds Are Forev...  39500000
# 300                Logam Mulia 2 gram diri bs plltterr   2395000
# 343               Logam Mulia 10 gram diri bs plltterr  10750000
# 345                           Lotus Archi 1gr CertiEye   1085000
#
#                                  seller            location  number_sold  \
# 18    hartadinata abadi official store        Kab. Bandung             0
# 19    hartadinata abadi official store        Kab. Bandung             0
# 108                    TOKO MAS DYNASTY       Jakarta Pusat          250
# 123                    TOKO MAS DYNASTY       Jakarta Pusat          100
# 181                    TOKO MAS DYNASTY       Jakarta Pusat           60
# 183                    TOKO MAS DYNASTY       Jakarta Pusat           30
# 185                    TOKO MAS DYNASTY       Jakarta Pusat          250
# 203                        AG Jewellery            Semarang            1
# 205                           Aurum Lab  Kab. Bandung Barat            2
# 217                           DNP-STORE      Kab. Tangerang            1
# 219                       Juene Jewelry             Bandung            2
# 220                    TOKO MAS DYNASTY       Jakarta Pusat           26
# 262                    TOKO MAS DYNASTY       Jakarta Pusat           70
# 264                Pamp Suisse Official       Jakarta Utara            1
# 265                        Titania Gold     Jakarta Selatan           40
# 267                              emasin     Jakarta Selatan          100
# 282                    TOKO MAS DYNASTY       Jakarta Pusat           27
# 285                Pamp Suisse Official       Jakarta Utara            0
# 300                    TOKO MAS DYNASTY       Jakarta Pusat           30
# 343                    TOKO MAS DYNASTY       Jakarta Pusat           12
# 345                          LotusArchi     Jakarta Selatan        10000
#
#      rating                                               link
# 18      5.0  https://www.blibli.com/p/emaskita-birthday-bul...
# 19      5.0  https://www.blibli.com/p/emaskita-wedding-inte...
# 108     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 123     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 181     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 183     4.9  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 185     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 203     0.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 205     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 217     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 219     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 220     4.9  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 262     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 264     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 265     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 267     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 282     4.9  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 285     0.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 300     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 343     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 345     5.0  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...

# %%
idx_to_drop = store_df[(store_df['product_name'].str.contains('ANTAM') == False) & (store_df['product_name'].str.contains('Antam') == False) &
                       (store_df['product_name'].str.contains('antam') == False)].index.tolist()

# %%
store_df_antam = store_df.drop(index=idx_to_drop)

# %%
store_df_antam.reset_index().drop(columns='index', inplace=True)

# %%
store_df_antam
# Out:
#                                           product_name     price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU   1095000
# 1    Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...   1115420
# 2    BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...   1095000
# 3    Hartadinata X Antam Logam Mulia Keping Emas [1...   1060000
# 4    SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...   1095000
# ..                                                 ...       ...
# 339                                  Emas antam 1 gram   1000000
# 340                                  emas antam 1 gram   1090000
# 341                            Antam Indonesia premium    150000
# 342  Emas Antam 50 Gram Certicard Reinvented Certie...  51533000
# 344  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...   1167500
#
#                           seller              location  number_sold  rating  \
# 0      de yellow official store    Kota Jakarta Utara         37000     4.9
# 1     victorindo official store    Kota Jakarta Pusat             2     5.0
# 2        bligold official store          Kota Bandung            77     4.9
# 3                      my jewel    Kota Jakarta Pusat           181     4.9
# 4        bligold official store         Kota Semarang            56     5.0
# ..                           ...                   ...          ...     ...
# 339                   TOKO SIJUN         Jakarta Barat           60     5.0
# 340                 Heddon_mania             Palembang            0     0.0
# 341                 Mulia Cikini         Jakarta Pusat           50     5.0
# 342                     RVL Gold         Jakarta Timur            0     0.0
# 344             Altisar Official         Jakarta Timur           15     5.0
#
#                                                   link
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...
# 1    https://www.blibli.com/p/logam-mulia-emas-anta...
# 2    https://www.blibli.com/p/bandung-bligold-antam...
# 3    https://www.blibli.com/p/hartadinata-x-antam-l...
# 4    https://www.blibli.com/p/semarang-bligold-anta...
# ..                                                 ...
# 339  https://www.tokopedia.com/archive-tokosijun/em...
# 340  https://www.tokopedia.com/heddonmania/emas-ant...
# 341  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 342  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
# 344  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
#
# [325 rows x 7 columns]

# %%
store_df_antam[(store_df_antam['product_name'].str.contains('1') == True) & (store_df_antam['product_name'].str.contains('10') == False) &
                                    (store_df_antam['product_name'].str.contains('0.5') == False) & (store_df_antam['product_name'].str.contains('0,5') == False)]
# Out:
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 1    Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...  1115420
# 2    BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...  1095000
# 3    Hartadinata X Antam Logam Mulia Keping Emas [1...  1060000
# 4    SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...  1095000
# ..                                                 ...      ...
# 337  logam mulia 1gr antam congratulations gift ema...  1363000
# 338                                  emas antam 1 gram   675000
# 339                                  Emas antam 1 gram  1000000
# 340                                  emas antam 1 gram  1090000
# 344  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...  1167500
#
#                           seller              location  number_sold  rating  \
# 0      de yellow official store    Kota Jakarta Utara         37000     4.9
# 1     victorindo official store    Kota Jakarta Pusat             2     5.0
# 2        bligold official store          Kota Bandung            77     4.9
# 3                      my jewel    Kota Jakarta Pusat           181     4.9
# 4        bligold official store         Kota Semarang            56     5.0
# ..                           ...                   ...          ...     ...
# 337                   kusumadewa         Jakarta Timur           60     4.9
# 338                   Robijaya46              Semarang            3     5.0
# 339                   TOKO SIJUN         Jakarta Barat           60     5.0
# 340                 Heddon_mania             Palembang            0     0.0
# 344             Altisar Official         Jakarta Timur           15     5.0
#
#                                                   link
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...
# 1    https://www.blibli.com/p/logam-mulia-emas-anta...
# 2    https://www.blibli.com/p/bandung-bligold-antam...
# 3    https://www.blibli.com/p/hartadinata-x-antam-l...
# 4    https://www.blibli.com/p/semarang-bligold-anta...
# ..                                                 ...
# 337  https://www.tokopedia.com/kusumadewa/logam-mul...
# 338  https://www.tokopedia.com/archive-robijaya46-1...
# 339  https://www.tokopedia.com/archive-tokosijun/em...
# 340  https://www.tokopedia.com/heddonmania/emas-ant...
# 344  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...
#
# [291 rows x 7 columns]

# %%
store_df_antam_1gr = store_df_antam[(store_df_antam['product_name'].str.contains('1') == True) & (store_df_antam['product_name'].str.contains('10') == False) &
                                    (store_df_antam['product_name'].str.contains('0.5') == False) & (store_df_antam['product_name'].str.contains('0,5') == False)]

# %%
store_df_antam_1gr['price_diff'] = store_df_antam_1gr['price'] - gold_price_latest['price'][0]
store_df_antam_1gr
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12400\311400694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store_df_antam_1gr['price_diff'] = store_df_antam_1gr['price'] - gold_price_latest['price'][0]
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 1    Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...  1115420
# 2    BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...  1095000
# 3    Hartadinata X Antam Logam Mulia Keping Emas [1...  1060000
# 4    SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...  1095000
# ..                                                 ...      ...
# 337  logam mulia 1gr antam congratulations gift ema...  1363000
# 338                                  emas antam 1 gram   675000
# 339                                  Emas antam 1 gram  1000000
# 340                                  emas antam 1 gram  1090000
# 344  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...  1167500
#
#                           seller              location  number_sold  rating  \
# 0      de yellow official store    Kota Jakarta Utara         37000     4.9
# 1     victorindo official store    Kota Jakarta Pusat             2     5.0
# 2        bligold official store          Kota Bandung            77     4.9
# 3                      my jewel    Kota Jakarta Pusat           181     4.9
# 4        bligold official store         Kota Semarang            56     5.0
# ..                           ...                   ...          ...     ...
# 337                   kusumadewa         Jakarta Timur           60     4.9
# 338                   Robijaya46              Semarang            3     5.0
# 339                   TOKO SIJUN         Jakarta Barat           60     5.0
# 340                 Heddon_mania             Palembang            0     0.0
# 344             Altisar Official         Jakarta Timur           15     5.0
#
#                                                   link  price_diff
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 1    https://www.blibli.com/p/logam-mulia-emas-anta...       52420
# 2    https://www.blibli.com/p/bandung-bligold-antam...       32000
# 3    https://www.blibli.com/p/hartadinata-x-antam-l...       -3000
# 4    https://www.blibli.com/p/semarang-bligold-anta...       32000
# ..                                                 ...         ...
# 337  https://www.tokopedia.com/kusumadewa/logam-mul...      300000
# 338  https://www.tokopedia.com/archive-robijaya46-1...     -388000
# 339  https://www.tokopedia.com/archive-tokosijun/em...      -63000
# 340  https://www.tokopedia.com/heddonmania/emas-ant...       27000
# 344  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...      104500
#
# [291 rows x 8 columns]

# %%
store_df_antam_1gr['popularity_score'] = store_df_antam_1gr['number_sold'] * store_df_antam_1gr['rating']
store_df_antam_1gr
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12400\3204235427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store_df_antam_1gr['popularity_score'] = store_df_antam_1gr['number_sold'] * store_df_antam_1gr['rating']
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 1    Logam Mulia Emas Antam 1 Gram [Cetakan Terbaru...  1115420
# 2    BANDUNG - BliGold Antam Logam Mulia [1 g] Cert...  1095000
# 3    Hartadinata X Antam Logam Mulia Keping Emas [1...  1060000
# 4    SEMARANG - BliGold Antam Logam Mulia [1 g] Cer...  1095000
# ..                                                 ...      ...
# 337  logam mulia 1gr antam congratulations gift ema...  1363000
# 338                                  emas antam 1 gram   675000
# 339                                  Emas antam 1 gram  1000000
# 340                                  emas antam 1 gram  1090000
# 344  LM Logam Mulia Emas Antam 1 gram gr Kado Gift ...  1167500
#
#                           seller              location  number_sold  rating  \
# 0      de yellow official store    Kota Jakarta Utara         37000     4.9
# 1     victorindo official store    Kota Jakarta Pusat             2     5.0
# 2        bligold official store          Kota Bandung            77     4.9
# 3                      my jewel    Kota Jakarta Pusat           181     4.9
# 4        bligold official store         Kota Semarang            56     5.0
# ..                           ...                   ...          ...     ...
# 337                   kusumadewa         Jakarta Timur           60     4.9
# 338                   Robijaya46              Semarang            3     5.0
# 339                   TOKO SIJUN         Jakarta Barat           60     5.0
# 340                 Heddon_mania             Palembang            0     0.0
# 344             Altisar Official         Jakarta Timur           15     5.0
#
#                                                   link  price_diff  \
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 1    https://www.blibli.com/p/logam-mulia-emas-anta...       52420
# 2    https://www.blibli.com/p/bandung-bligold-antam...       32000
# 3    https://www.blibli.com/p/hartadinata-x-antam-l...       -3000
# 4    https://www.blibli.com/p/semarang-bligold-anta...       32000
# ..                                                 ...         ...
# 337  https://www.tokopedia.com/kusumadewa/logam-mul...      300000
# 338  https://www.tokopedia.com/archive-robijaya46-1...     -388000
# 339  https://www.tokopedia.com/archive-tokosijun/em...      -63000
# 340  https://www.tokopedia.com/heddonmania/emas-ant...       27000
# 344  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...      104500
#
#      popularity_score
# 0            181300.0
# 1                10.0
# 2               377.3
# 3               886.9
# 4               280.0
# ..                ...
# 337             294.0
# 338              15.0
# 339             300.0
# 340               0.0
# 344              75.0
#
# [291 rows x 9 columns]

# %%
store_df_antam_1gr_positive = store_df_antam_1gr[store_df_antam_1gr['price_diff'] >= 0].sort_values(by=['popularity_score','price_diff'],
                                                                                                    ascending=[False, True])

# %%
store_df_antam_1gr_positive['price_diff'].replace(0, 0.1, inplace=True)
store_df_antam_1gr_positive
# Out:
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 5            BliGold Antam Logam Mulia [1 g] CertiCard  1095000
# 126  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1085000
# 120  Emas Antam 1 Gram Logam Mulia LM Antam, Certic...  1090000
# 164  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1105000
# ..                                                 ...      ...
# 68   LOGAM MULIA ANTAM GIFT SERIES 1 GRAM LM EMAS G...  1299900
# 92   Emas Antam 1 Gram Gift Series - Gift Card Cong...  1431000
# 99   Emas Antam 1 Gram Gift Series - Gift Card Happ...  1608000
# 122  Logam Mulia Koin Emas Antam Elang 1 gram, Anta...  3500000
# 76   Emas ANTAM Certicard 1 gram x 5 pcs [Paket Hep...  5000000
#
#                          seller              location  number_sold  rating  \
# 0     de yellow official store    Kota Jakarta Utara         37000     4.9
# 5       bligold official store    Kota Jakarta Timur         23000     4.9
# 126                 WanWin Shop         Jakarta Barat        10000     5.0
# 120               KARALIA STORE       Jakarta Selatan        10000     5.0
# 164                 Winwin Shop         Jakarta Barat        10000     5.0
# ..                          ...                   ...          ...     ...
# 68                   Royal Spot              Surabaya            0     0.0
# 92                   Fuyyu Shop       Jakarta Selatan            0     0.0
# 99                   Fuyyu Shop       Jakarta Selatan            0     0.0
# 122           Fine Gold Gallery         Jakarta Utara            0     0.0
# 76               De paloma shop            Yogyakarta            0     0.0
#
#                                                   link  price_diff  \
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 5    https://www.blibli.com/p/bligold-antam-logam-m...       32000
# 126  https://www.tokopedia.com/wanwinshop/1-gr-gram...       22000
# 120  https://www.tokopedia.com/karalia/emas-antam-1...       27000
# 164  https://www.tokopedia.com/winwinshop/1-gr-gram...       42000
# ..                                                 ...         ...
# 68   https://www.bukalapak.com/p/logam-mulia/emas/4...      236900
# 92   https://www.bukalapak.com/p/fashion-wanita/per...      368000
# 99   https://www.bukalapak.com/p/fashion-wanita/per...      545000
# 122  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...     2437000
# 76   https://www.bukalapak.com/p/logam-mulia/4hhvsx...     3937000
#
#      popularity_score
# 0            181300.0
# 5            112700.0
# 126           50000.0
# 120           50000.0
# 164           50000.0
# ..                ...
# 68                0.0
# 92                0.0
# 99                0.0
# 122               0.0
# 76                0.0
#
# [214 rows x 9 columns]

# %%
store_df_antam_1gr_positive['final_score'] = store_df_antam_1gr['popularity_score'] / store_df_antam_1gr['price_diff']
store_df_antam_1gr_positive
# Out:
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 5            BliGold Antam Logam Mulia [1 g] CertiCard  1095000
# 126  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1085000
# 120  Emas Antam 1 Gram Logam Mulia LM Antam, Certic...  1090000
# 164  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1105000
# ..                                                 ...      ...
# 68   LOGAM MULIA ANTAM GIFT SERIES 1 GRAM LM EMAS G...  1299900
# 92   Emas Antam 1 Gram Gift Series - Gift Card Cong...  1431000
# 99   Emas Antam 1 Gram Gift Series - Gift Card Happ...  1608000
# 122  Logam Mulia Koin Emas Antam Elang 1 gram, Anta...  3500000
# 76   Emas ANTAM Certicard 1 gram x 5 pcs [Paket Hep...  5000000
#
#                          seller              location  number_sold  rating  \
# 0     de yellow official store    Kota Jakarta Utara         37000     4.9
# 5       bligold official store    Kota Jakarta Timur         23000     4.9
# 126                 WanWin Shop         Jakarta Barat        10000     5.0
# 120               KARALIA STORE       Jakarta Selatan        10000     5.0
# 164                 Winwin Shop         Jakarta Barat        10000     5.0
# ..                          ...                   ...          ...     ...
# 68                   Royal Spot              Surabaya            0     0.0
# 92                   Fuyyu Shop       Jakarta Selatan            0     0.0
# 99                   Fuyyu Shop       Jakarta Selatan            0     0.0
# 122           Fine Gold Gallery         Jakarta Utara            0     0.0
# 76               De paloma shop            Yogyakarta            0     0.0
#
#                                                   link  price_diff  \
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 5    https://www.blibli.com/p/bligold-antam-logam-m...       32000
# 126  https://www.tokopedia.com/wanwinshop/1-gr-gram...       22000
# 120  https://www.tokopedia.com/karalia/emas-antam-1...       27000
# 164  https://www.tokopedia.com/winwinshop/1-gr-gram...       42000
# ..                                                 ...         ...
# 68   https://www.bukalapak.com/p/logam-mulia/emas/4...      236900
# 92   https://www.bukalapak.com/p/fashion-wanita/per...      368000
# 99   https://www.bukalapak.com/p/fashion-wanita/per...      545000
# 122  https://ta.tokopedia.com/promo/v1/clicks/8a-xg...     2437000
# 76   https://www.bukalapak.com/p/logam-mulia/4hhvsx...     3937000
#
#      popularity_score  final_score
# 0            181300.0     5.665625
# 5            112700.0     3.521875
# 126           50000.0     2.272727
# 120           50000.0     1.851852
# 164           50000.0     1.190476
# ..                ...          ...
# 68                0.0     0.000000
# 92                0.0     0.000000
# 99                0.0     0.000000
# 122               0.0     0.000000
# 76                0.0     0.000000
#
# [214 rows x 10 columns]

# %%
store_df_antam_1gr_positive.sort_values('final_score',ascending=False).head()
# Out:
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 5            BliGold Antam Logam Mulia [1 g] CertiCard  1095000
# 126  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1085000
# 120  Emas Antam 1 Gram Logam Mulia LM Antam, Certic...  1090000
# 117          LM EMAS ANTAM 1 Gram, LOGAM MULIA TERBARU  1090000
#
#                          seller              location  number_sold  rating  \
# 0     de yellow official store    Kota Jakarta Utara         37000     4.9
# 5       bligold official store    Kota Jakarta Timur         23000     4.9
# 126                 WanWin Shop         Jakarta Barat        10000     5.0
# 120               KARALIA STORE       Jakarta Selatan        10000     5.0
# 117                 IndoBullion         Jakarta Utara         7000     5.0
#
#                                                   link  price_diff  \
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 5    https://www.blibli.com/p/bligold-antam-logam-m...       32000
# 126  https://www.tokopedia.com/wanwinshop/1-gr-gram...       22000
# 120  https://www.tokopedia.com/karalia/emas-antam-1...       27000
# 117  https://www.tokopedia.com/archive-indobullion/...       27000
#
#      popularity_score  final_score
# 0            181300.0     5.665625
# 5            112700.0     3.521875
# 126           50000.0     2.272727
# 120           50000.0     1.851852
# 117           35000.0     1.296296

# %%
# import library
import pandas as pd


# data loading
bli_df = pd.read_csv('../data_engineering/BlibliMas_clean_latest.csv')
bulak_df = pd.read_csv('../data_engineering/BukalapakMas_clean_latest.csv')
tokped_df = pd.read_csv('../data_engineering/TokMas_clean_latest.csv')
gold_price_latest = pd.read_csv('../data_engineering/HargaEmas_clean_latest.csv')

# gabungin data
store_df = pd.concat([bli_df, bulak_df, tokped_df], ignore_index=True)

# data filtering

## drop produk yang bukan antam
idx_to_drop = store_df[(store_df['product_name'].str.contains('ANTAM') == False) & (store_df['product_name'].str.contains('Antam') == False) &
                       (store_df['product_name'].str.contains('antam') == False)].index.tolist()
store_df.drop(index=idx_to_drop, inplace=True)
store_df.reset_index().drop(columns='index', inplace=True)

## filter produk yang bukan 1 gram
store_df = store_df[(store_df['product_name'].str.contains('1') == True) & (store_df['product_name'].str.contains('10') == False) &
                    (store_df['product_name'].str.contains('0.5') == False) & (store_df['product_name'].str.contains('0,5') == False)]

# bikin metric baru
store_df['price_diff'] = store_df['price'] - gold_price_latest['price'][0]
store_df['popularity_score'] = store_df['number_sold'] * store_df['rating']

## filter produk yang selisih harganya positif
store_df = store_df[store_df['price_diff'] >= 0]
store_df['price_diff'].replace(0, 0.1, inplace=True)

# bikin metric final score
store_df['final_score'] = store_df['popularity_score'] / store_df['price_diff']
store_df.sort_values('final_score', ascending=False).head()
# Out:
#                                           product_name    price  \
# 0            ANTAM LM EMAS 1 Gram, LOGAM MULIA TERBARU  1095000
# 5            BliGold Antam Logam Mulia [1 g] CertiCard  1095000
# 126  1 GR (GRAM) GOLDBAR/LOGAM MULIA/LM/EMAS ANTAM ...  1085000
# 120  Emas Antam 1 Gram Logam Mulia LM Antam, Certic...  1090000
# 117          LM EMAS ANTAM 1 Gram, LOGAM MULIA TERBARU  1090000
#
#                          seller              location  number_sold  rating  \
# 0     de yellow official store    Kota Jakarta Utara         37000     4.9
# 5       bligold official store    Kota Jakarta Timur         23000     4.9
# 126                 WanWin Shop         Jakarta Barat        10000     5.0
# 120               KARALIA STORE       Jakarta Selatan        10000     5.0
# 117                 IndoBullion         Jakarta Utara         7000     5.0
#
#                                                   link  price_diff  \
# 0    https://www.blibli.com/p/antam-lm-emas-1-gram-...       32000
# 5    https://www.blibli.com/p/bligold-antam-logam-m...       32000
# 126  https://www.tokopedia.com/wanwinshop/1-gr-gram...       22000
# 120  https://www.tokopedia.com/karalia/emas-antam-1...       27000
# 117  https://www.tokopedia.com/archive-indobullion/...       27000
#
#      popularity_score  final_score
# 0            181300.0     5.665625
# 5            112700.0     3.521875
# 126           50000.0     2.272727
# 120           50000.0     1.851852
# 117           35000.0     1.296296
